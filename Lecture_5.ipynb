# %% [markdown]
# ## Lecture 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input("Your age:"))
#discount = 0
if age<10:
    discount = 0.15
elif age<18:
    discount = 0.08
elif age<23:
    discount = 0.05
elif age<=60:
    discount = 0.02
else:
    discount = 0.25
    
print(discount*100,"%")
# Out:
# 2.0 %

# %%
age = int(input("Your age:"))
discount = 0.25
if age<10:
    discount = 0.15
elif age<18:
    discount = 0.08
elif age<23:
    discount = 0.05
elif age<=60:
    discount = 0.02
    
print(discount*100,"%")
# Out:
# 25.0 %

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input("Your age:"))
gen = input("Your gender(M/F):")
gift = True
discount = 0.25
if age<10:
    discount = 0.15
elif age<18:
    discount = 0.08
    if gen == 'M':
        gift = False
elif age<23:
    discount = 0.05
    if gen == 'M':
        gift = False
elif age<=60:
    discount = 0.02
    gift = False
    
print(discount*100,"%")
